# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## Day 8 Visualizing "Box Plot"

# %%
df = sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## A boxplot is a visual representation of the distribution of a dataset through five summary statistics: minimum, first quartile, median, third quartile, and maximum. It's used to identify outliers, compare distributions, and understand the central tendency and spread of data, commonly employed in exploratory data analysis and statistical inference.

# %%
#box plot of complete dataset
sns.boxplot(data=df)
# Out:
# <Axes: >

# %% [markdown]
# from the above box plot we can see that we have some outliers in "sepal_width"

# %%
#viualizing sepal_width for outlier detection
sns.boxplot(data=df,x="sepal_width")
# Out:
# <Axes: xlabel='sepal_width'>

# %% [markdown]
# we can see that their are outliers which is smaller than 2.0 and greater than 4.0

# %% [markdown]
# ## we will learn how to remove that in day_9

# %%
#random outlier
x=np.random.rand(100)
sns.boxplot(x)
# Out:
# <Axes: >
